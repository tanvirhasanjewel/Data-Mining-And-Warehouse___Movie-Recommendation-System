# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
movie_df_raw = pd.read_csv("/content/drive/MyDrive/Data Mining/week 02 - 12-02-2025/03 Recommendation System 2/ratings.csv")
movie_names = pd.read_csv("/content/drive/MyDrive/Data Mining/week 02 - 12-02-2025/03 Recommendation System 2/movies.csv")

# %%
movie_df_raw
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
movie_names
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %% [markdown]
# # 1.	Compute the based on a movie similarity matrix.

# %%
ratings = pd.read_csv('/content/drive/MyDrive/Data Mining/week 02 - 12-02-2025/03 Recommendation System 2/ratings.csv')

user_movie_matrix = ratings.pivot(index='userId', columns='movieId', values='rating')

movie_similarity = user_movie_matrix.corr(method='pearson')

movie_similarity
# Out:
# movieId    1         2         3         4         5         6         7       \
# movieId
# 1        1.000000  0.330978  0.487109  1.000000  0.310971  0.106465  0.208402
# 2        0.330978  1.000000  0.419564       NaN  0.562791  0.163510  0.430261
# 3        0.487109  0.419564  1.000000       NaN  0.602266  0.345069  0.554088
# 4        1.000000       NaN       NaN  1.000000  0.654654       NaN  0.203653
# 5        0.310971  0.562791  0.602266  0.654654  1.000000  0.291302  0.609119
# ...           ...       ...       ...       ...       ...       ...       ...
# 193581        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 193583        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 193585        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 193587        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 193609        NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# movieId    8         9         10      ...  193565  193567  193571  193573  \
# movieId                                ...
# 1        0.968246  0.095913 -0.021409  ...     NaN     NaN     NaN     NaN
# 2        0.415227  0.277350  0.016626  ...     NaN     NaN     NaN     NaN
# 3        0.333333  0.458591 -0.050276  ...     NaN     NaN     NaN     NaN
# 4             NaN       NaN  0.870388  ...     NaN     NaN     NaN     NaN
# 5        0.555556  0.319173  0.218263  ...     NaN     NaN     NaN     NaN
# ...           ...       ...       ...  ...     ...     ...     ...     ...
# 193581        NaN       NaN       NaN  ...     NaN     NaN     NaN     NaN
# 193583        NaN       NaN       NaN  ...     NaN     NaN     NaN     NaN
# 193585        NaN       NaN       NaN  ...     NaN     NaN     NaN     NaN
# 193587        NaN       NaN       NaN  ...     NaN     NaN     NaN     NaN
# 193609        NaN       NaN       NaN  ...     NaN     NaN     NaN     NaN
#
# movieId  193579  193581  193583  193585  193587  193609
# movieId
# 1           NaN     NaN     NaN     NaN     NaN     NaN
# 2           NaN     NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN     NaN     NaN
# 5           NaN     NaN     NaN     NaN     NaN     NaN
# ...         ...     ...     ...     ...     ...     ...
# 193581      NaN     NaN     NaN     NaN     NaN     NaN
# 193583      NaN     NaN     NaN     NaN     NaN     NaN
# 193585      NaN     NaN     NaN     NaN     NaN     NaN
# 193587      NaN     NaN     NaN     NaN     NaN     NaN
# 193609      NaN     NaN     NaN     NaN     NaN     NaN
#
# [9724 rows x 9724 columns]

# %% [markdown]
# # 2.	Display the recommended movies.

# %%
ratings = pd.read_csv("/content/drive/MyDrive/Data Mining/week 02 - 12-02-2025/03 Recommendation System 2/ratings.csv")
movies = pd.read_csv("/content/drive/MyDrive/Data Mining/week 02 - 12-02-2025/03 Recommendation System 2/movies.csv")

def recommend_movies(movie_id, top_n=5):

    if movie_id not in movie_similarity:
        return "Movie not found."

    similar_movies = movie_similarity[movie_id].dropna().sort_values(ascending=False)[1:top_n+1]

    recommended = movies[movies["movieId"].isin(similar_movies.index)][["movieId", "title"]]

    return recommended

recommendations = recommend_movies(1, top_n=5)
recommendations
# Out:
#       movieId                                     title
# 1112     1447                         Gridlock'd (1997)
# 1201     1599                              Steel (1997)
# 5277     8695  Bachelor and the Bobby-Soxer, The (1947)
# 6141    43919                         Date Movie (2006)
# 7981    96655                      Robot & Frank (2012)

# %% [markdown]
# # **To generate personalized recommendations:**
#
# 1.   Select a specific user from the dataset.
# 2.   Identify the the user has rated the highest.
# 3.   Find movies that the user has NOT rated yet.
# 4.   From the similar movies, recommend the with the highest average rating.

# %%
# 01
user_id = 47
user_ratings = ratings[ratings["userId"] == user_id]
user_ratings
# Out:
#       userId  movieId  rating   timestamp
# 6918      47       31     3.0  1496205717
# 6919      47       47     3.0  1496209354
# 6920      47       62     3.0  1496205312
# 6921      47      141     2.0  1496208714
# 6922      47      147     3.5  1496205843
# ...      ...      ...     ...         ...
# 7053      47   160980     3.5  1496209791
# 7054      47   161582     3.5  1496208845
# 7055      47   163645     3.0  1496205601
# 7056      47   166643     3.0  1496205070
# 7057      47   171011     3.0  1496206929
#
# [140 rows x 4 columns]

# %%
#02
user_id = 47
user_ratings = ratings[ratings["userId"] == user_id]

highest_rated_item = user_ratings.loc[user_ratings["rating"].idxmax()]

highest_rated_item
# Out:
# userId       4.700000e+01
# movieId      3.147000e+03
# rating       5.000000e+00
# timestamp    1.496205e+09
# Name: 6958, dtype: float64

# %%
#03
all_movies = set(movies["movieId"])

rated_movies = set(user_ratings["movieId"])

unrated_movies = all_movies - rated_movies

unrated_movies_details = movies[movies["movieId"].isin(unrated_movies)]
unrated_movies_details
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9602 rows x 3 columns]

# %%
#04
def recommend_movies_with_highest_avg_rating(user_id, top_n=5):

    user_ratings = ratings[ratings["userId"] == user_id]

    rated_movies = set(user_ratings["movieId"])

    all_movies = set(movies["movieId"])

    unrated_movies = all_movies - rated_movies

    unrated_movies_details = movies[movies["movieId"].isin(unrated_movies)]

    avg_ratings = ratings.groupby("movieId")["rating"].mean()

    recommended_movies = unrated_movies_details.merge(
        avg_ratings, on="movieId", how="left"
    ).sort_values(by="rating", ascending=False).head(top_n)

    return recommended_movies[["movieId", "title", "rating"]]


recommended_movies = recommend_movies_with_highest_avg_rating(user_id=47, top_n=5)
recommended_movies
# Out:
#       movieId                                 title  rating
# 4703     7096               Rivers and Tides (2001)     5.0
# 8810   136359      Scooby-Doo Goes Hollywood (1979)     5.0
# 8911   141718                      Deathgasm (2015)     5.0
# 5563    27320  Nine Lives of Tomas Katz, The (2000)     5.0
# 8915   141816                      12 Chairs (1976)     5.0
